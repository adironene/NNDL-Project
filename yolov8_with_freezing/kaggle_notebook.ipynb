# %%
from ultralytics import YOLO

model = YOLO('/kaggle/working/inputdata/weights/yolov8n.pt')

full_model = model.model.model
for i, layer in enumerate(full_model):
    print(f"Layer {i}: {type(layer).__name__}")
# Out:
# Layer 0: Conv
# Layer 1: Conv
# Layer 2: C2f
# Layer 3: Conv
# Layer 4: C2f
# Layer 5: Conv
# Layer 6: C2f
# Layer 7: Conv
# Layer 8: C2f
# Layer 9: SPPF
# Layer 10: Upsample
# Layer 11: Concat
# Layer 12: C2f
# Layer 13: Upsample
# Layer 14: Concat
# Layer 15: C2f
# Layer 16: Conv
# Layer 17: Concat
# Layer 18: C2f
# Layer 19: Conv
# Layer 20: Concat
# Layer 21: C2f
# Layer 22: Detect

# %%
import math
#Recommended freeze ratio for a medium sized dataset like ours with 5385 examples in the training dataset is 0.2-0.4
min_freeze = math.floor(len(full_model) * 0.2)
max_freeze = math.ceil(len(full_model) * 0.4)

for num_layers_to_freeze in range(min_freeze, max_freeze):
    for i, layer in enumerate(full_model):
        if i < num_layers_to_freeze:
            for param in layer.parameters():
                param.requires_grad = False
        else:
            for param in layer.parameters():
                param.requires_grad = True

    model.train(
        data='/kaggle/working/inputdata/yolov8.yaml',
        epochs=100,
        imgsz=416,
        batch=32,
        name='train_with_freeze_' + str(num_layers_to_freeze) + "_layers",
        patience=10,
        verbose=True
    )
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#best performing model from training was the yolov8 model with the first 4 layers frozen
model = YOLO("/kaggle/working/inputdata/runs/detect/train_with_freeze_4_layers/weights/best.pt")

results = model.predict(
    source="/kaggle/working/inputdata/dataset/images/test",
    conf=0.225,                     # confidence threshold based on peak of f1_curve
    save=True,                     
    save_txt=True,                 
    project="runs/detect/test",        
    name="test_results",           
    imgsz=416                      
)

model.val(
    data="/kaggle/working/inputdata/yolov8.yaml",   
    split="test",         
    imgsz=416             
)
# Out:
# image 1/258 /kaggle/working/inputdata/dataset/images/test/clip2--121-_jpg.rf.6bca04218060d7026b606fde78f09de4.jpg: 416x416 (no detections), 8.4ms
# image 2/258 /kaggle/working/inputdata/dataset/images/test/clip2--125-_jpg.rf.98cc7b2c382ab8fcfcd4565534bc4149.jpg: 416x416 1 enemy, 6.4ms
# image 3/258 /kaggle/working/inputdata/dataset/images/test/clip2--134-_jpg.rf.c43a75b31538a4b3b04f11140f076c53.jpg: 416x416 1 enemy, 1 enemy_head, 6.4ms
# image 4/258 /kaggle/working/inputdata/dataset/images/test/clip2--143-_jpg.rf.d509daf3997292518747ffc4e60fbab4.jpg: 416x416 1 enemy, 1 enemy_head, 6.2ms
# image 5/258 /kaggle/working/inputdata/dataset/images/test/clip2--155-_jpg.rf.de2b5d2506b33ac87e60c62767378265.jpg: 416x416 1 enemy, 1 enemy_head, 6.2ms
# image 6/258 /kaggle/working/inputdata/dataset/images/test/clip2--166-_jpg.rf.713d499f10a6e875a851bcfb8b0cfdaf.jpg: 416x416 1 enemy, 6.5ms
# ...

# %%
import shutil
import os

output_dir = '/kaggle/working/inputdata'
zip_path = '/kaggle/working/output'

if os.path.exists(output_dir):
    shutil.make_archive('/kaggle/working/output', 'zip', output_dir)
    print(f"Zipped {output_dir} to {zip_path}")
else:
    print("No output directory found to zip.")
# Out:
# Zipped /kaggle/working/inputdata to /kaggle/working/output
